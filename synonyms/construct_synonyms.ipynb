# %%
import json

with open(r'C:\conjunct\vandy\yang\corpora\brenda\brenda_2023_1.json') as f:
    brenda = json.load(f)

# %%
brenda['version']
# Out:
# '1.1.0'

# %%
brenda['data']['1.1.1.1']['synonyms']
# Out:
# [{'value': 'aldehyde reductase'},
#  {'value': 'dehydrogenase, alcohol'},
#  {'value': 'alcohol dehydrogenase (NAD)'},
#  {'value': 'aliphatic alcohol dehydrogenase'},
#  {'value': 'ethanol dehydrogenase'},
#  {'value': 'NAD-specific aromatic alcohol dehydrogenase'},
#  {'value': 'NADH-alcohol dehydrogenase'},
#  {'value': 'NADH-aldehyde dehydrogenase'},
#  {'value': 'primary alcohol dehydrogenase'},
#  {'value': 'yeast alcohol dehydrogenase'},
#  {'value': 'FDH'},
#  {'value': 'FALDH'},
#  {'value': '40 kDa allergen'},
#  {'value': 'ADH-A2'},
#  {'value': 'ADH-B2'},
#  {'value': 'ADH-C2'},
#  {'value': 'ADH-HT'},
#  {'value': 'Alcohol dehydrogenase-B2'},
#  {'value': 'Gastric alcohol dehydrogenase'},
#  {'value': 'Glutathione-dependent formaldehyde dehydrogenase'},
#  {'value': 'GSH-FDH'},
#  {'value': 'Octanol dehydrogenase'},
#  {'value': 'Retinol dehydrogenase'},
#  {'proteins': ['10'],
#   'organisms': ['10'],
#   'references': ['223'],
#   'value': 'alcohol dehydrogenase'},
# ...
